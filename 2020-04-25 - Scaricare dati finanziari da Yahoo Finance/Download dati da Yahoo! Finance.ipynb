# %%
#pip install pandas-datareader

# %%
from pandas_datareader import data

# %%
df_aapl = data.get_data_yahoo("AAPL")

# %%
df_aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2015-04-27  133.130005  131.149994  132.309998  132.649994   96954200.0
# 2015-04-28  134.539993  129.570007  134.460007  130.559998  118924000.0
# 2015-04-29  131.589996  128.300003  130.160004  128.639999   63386100.0
# 2015-04-30  128.639999  124.580002  128.639999  125.150002   83195400.0
# 2015-05-01  130.130005  125.300003  126.099998  128.949997   58512600.0
# ...                ...         ...         ...         ...          ...
# 2020-04-20  281.679993  276.850006  277.950012  276.929993   32503800.0
# 2020-04-21  277.250000  265.429993  276.279999  268.369995   45247900.0
# 2020-04-22  277.899994  272.200012  273.609985  276.100006   29264300.0
# 2020-04-23  281.750000  274.869995  275.869995  275.029999   31128600.0
# 2020-04-24  282.970001  277.000000  277.200012  282.970001   30338976.0
#
#              Adj Close
# Date
# 2015-04-27  122.072395
# 2015-04-28  120.149078
# ...

# %%
df_isp = data.get_data_yahoo("ISP.MI", start="2019-01-01", end="2019-12-31")

# %%
df_isp
# Out:
#               High     Low    Open   Close       Volume  Adj Close
# Date
# 2019-01-02  1.9330  1.8828  1.9276  1.9064   98236797.0   1.733370
# 2019-01-03  1.9458  1.8950  1.8952  1.9014  120516423.0   1.728824
# 2019-01-04  1.9992  1.9200  1.9230  1.9992  135132352.0   1.817748
# 2019-01-07  2.0430  2.0010  2.0100  2.0330  106166510.0   1.848480
# 2019-01-08  2.0570  2.0040  2.0370  2.0095  110672611.0   1.827113
# ...            ...     ...     ...     ...          ...        ...
# 2019-12-19  2.3800  2.3580  2.3610  2.3800   87441143.0   2.380000
# 2019-12-20  2.4050  2.3745  2.4000  2.4050  220630496.0   2.405000
# 2019-12-23  2.4025  2.3805  2.3930  2.4005   59129289.0   2.400500
# 2019-12-27  2.3995  2.3550  2.3905  2.3550   85908015.0   2.355000
# 2019-12-30  2.3665  2.3485  2.3550  2.3485   45563575.0   2.348500
#
# [252 rows x 6 columns]

# %%
#pip install yfinance==0.1.52

# %%
import yfinance as yf

# %%
data = yf.download("AAPL", start="2019-01-01", end="2019-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  158.529999  159.360001  156.479996  157.740005  155.037109
# 2019-01-02  154.889999  158.850006  154.229996  157.919998  155.214005
# 2019-01-03  143.979996  145.720001  142.000000  142.190002  139.753540
# 2019-01-04  144.529999  148.550003  143.800003  148.259995  145.719513
# 2019-01-07  148.699997  148.830002  145.899994  147.929993  145.395203
# ...                ...         ...         ...         ...         ...
# 2019-12-23  280.529999  284.250000  280.369995  284.000000  283.327576
# 2019-12-24  284.690002  284.890015  282.920013  284.269989  283.596924
# 2019-12-26  284.820007  289.980011  284.700012  289.910004  289.223602
# 2019-12-27  291.119995  293.970001  288.119995  289.799988  289.113831
# 2019-12-30  289.459991  292.690002  285.220001  291.519989  290.829773
#
#               Volume
# Date
# 2018-12-31  35003500
# 2019-01-02  37039700
# 2019-01-03  91312200
# ...

# %%
data = yf.download("AAPL MSFT AMZN")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data
# Out:
#              Adj Close                                Close               \
#                   AAPL         AMZN        MSFT        AAPL         AMZN
# Date
# 1980-12-12    0.406782          NaN         NaN    0.513393          NaN
# 1980-12-15    0.385558          NaN         NaN    0.486607          NaN
# 1980-12-16    0.357260          NaN         NaN    0.450893          NaN
# 1980-12-17    0.366103          NaN         NaN    0.462054          NaN
# 1980-12-18    0.376715          NaN         NaN    0.475446          NaN
# ...                ...          ...         ...         ...          ...
# 2020-04-20  276.929993  2393.610107  175.059998  276.929993  2393.610107
# 2020-04-21  268.369995  2328.120117  167.820007  268.369995  2328.120117
# 2020-04-22  276.100006  2363.489990  173.520004  276.100006  2363.489990
# 2020-04-23  275.029999  2399.449951  171.419998  275.029999  2399.449951
# 2020-04-24  282.970001  2410.219971  174.550003  282.970001  2410.219971
#
# ...

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
dir(aapl)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_expirations',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_major_holders',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_sustainability',
#  'actions',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'financials',
#  'get_actions',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
# ...

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
aapl.dividends
# Out:
# Date
# 1987-05-11    0.00214
# 1987-08-10    0.00214
# 1987-11-17    0.00286
# 1988-02-12    0.00286
# 1988-05-16    0.00286
#                ...
# 2019-02-08    0.73000
# 2019-05-10    0.77000
# 2019-08-09    0.77000
# 2019-11-07    0.77000
# 2020-02-07    0.77000
# Name: Dividends, Length: 66, dtype: float64

# %%
aapl.history()
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-03-25  250.75  258.25  244.30  245.52  75900500          0             0
# 2020-03-26  246.52  258.68  246.36  258.44  63021800          0             0
# 2020-03-27  252.75  255.87  247.05  247.74  51054200          0             0
# 2020-03-30  250.74  255.52  249.40  254.81  41994100          0             0
# 2020-03-31  255.60  262.49  252.00  254.29  49250500          0             0
# 2020-04-01  246.50  248.72  239.13  240.91  44054600          0             0
# 2020-04-02  240.34  245.15  236.90  244.93  41483500          0             0
# 2020-04-03  242.80  245.70  238.97  241.41  32470000          0             0
# 2020-04-06  250.90  263.11  249.38  262.47  50455100          0             0
# 2020-04-07  270.80  271.70  259.00  259.43  50721800          0             0
# 2020-04-08  262.74  267.37  261.23  266.07  42223800          0             0
# ...

# %%
aapl.financials
# Out:
#                                          2019-09-28   2018-09-29   2017-09-30  \
# Research Development                     1.6217e+10   1.4236e+10   1.1581e+10
# Effect Of Accounting Charges                   None         None         None
# Income Before Tax                        6.5737e+10   7.2903e+10   6.4089e+10
# Minority Interest                              None         None         None
# Net Income                               5.5256e+10   5.9531e+10   4.8351e+10
# Selling General Administrative           1.8245e+10   1.6705e+10   1.5261e+10
# Gross Profit                             9.8392e+10  1.01839e+11   8.8186e+10
# Ebit                                      6.393e+10   7.0898e+10   6.1344e+10
# Operating Income                          6.393e+10   7.0898e+10   6.1344e+10
# Other Operating Expenses                       None         None         None
# Interest Expense                         -3.576e+09    -3.24e+09   -2.323e+09
# ...

# %%
aapl.balance_sheet
# Out:
#                              2019-09-28    2018-09-29    2017-09-30  \
# Total Liab                 2.480280e+11  2.585780e+11  2.412720e+11
# Total Stockholder Equity   9.048800e+10  1.071470e+11  1.340470e+11
# Other Current Liab         4.324200e+10  3.929300e+10  3.809900e+10
# Total Assets               3.385160e+11  3.657250e+11  3.753190e+11
# Common Stock               4.517400e+10  4.020100e+10  3.586700e+10
# Other Current Assets       1.235200e+10  1.208700e+10  1.393600e+10
# Retained Earnings          4.589800e+10  7.040000e+10  9.833000e+10
# Other Liab                 5.050300e+10  4.891400e+10  4.325100e+10
# Treasury Stock            -5.840000e+08 -3.454000e+09 -1.500000e+08
# Other Assets               3.297800e+10  2.228300e+10  1.817700e+10
# Cash                       4.884400e+10  2.591300e+10  2.028900e+10
# Total Current Liabilities  1.057180e+11  1.159290e+11  1.008140e+11
# Short Long Term Debt       1.026000e+10  8.784000e+09  6.496000e+09
# ...

# %%
aapl.cashflow
# Out:
#                                              2019-09-28    2018-09-29  \
# Investments                                5.809300e+10  3.084500e+10
# Change To Liabilities                     -2.548000e+09  9.172000e+09
# Total Cashflows From Investing Activities  4.589600e+10  1.606600e+10
# Net Borrowings                            -7.819000e+09  4.320000e+08
# Total Cash From Financing Activities      -9.097600e+10 -8.787600e+10
# Change To Operating Activities            -8.960000e+08  3.001600e+10
# Issuance Of Stock                          7.810000e+08  6.690000e+08
# Net Income                                 5.525600e+10  5.953100e+10
# Change In Cash                             2.431100e+10  5.624000e+09
# Repurchase Of Stock                       -6.971400e+10 -7.526500e+10
# Total Cash From Operating Activities       6.939100e+10  7.743400e+10
# Depreciation                               1.254700e+10  1.090300e+10
# ...
