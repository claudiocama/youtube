# %%
import pandas as pd

# %%
df = pd.read_csv("S&P500_financials.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Symbol                 Name                  Sector   Price  \
# 0           0    MMM           3M Company             Industrials  222.89
# 1           1    AOS      A.O. Smith Corp             Industrials   60.24
# 2           2    ABT  Abbott Laboratories             Health Care   56.27
# 3           3   ABBV          AbbVie Inc.             Health Care  108.48
# 4           4    ACN        Accenture plc  Information Technology  150.51
#
#    Price/Earnings  Dividend Yield  Earnings/Share    Market Cap        EBITDA  \
# 0           24.31        2.332862            7.92  138721055226  9.048000e+09
# 1           27.76        1.147959            1.70   10783419933  6.010000e+08
# 2           22.51        1.908982            0.26  102121042306  5.744000e+09
# 3           19.41        2.499560            3.29  181386347059  1.031000e+10
# 4           25.47        1.714470            5.44   98765855553  5.643228e+09
#
#    Price/Sales  Price/Book
# ...

# %%
df.sort_values(by="Price")
# Out:
#      Unnamed: 0 Symbol                        Name                  Sector  \
# 104         104    CHK           Chesapeake Energy                  Energy
# 10           10    AES                    AES Corp               Utilities
# 200         200      F                  Ford Motor  Consumer Discretionary
# 9             9    AMD  Advanced Micro Devices Inc  Information Technology
# 459         459     UA        Under Armour Class C  Consumer Discretionary
# ..          ...    ...                         ...                     ...
# 61           61    AZO                AutoZone Inc  Consumer Discretionary
# 28           28   GOOG        Alphabet Inc Class C  Information Technology
# 27           27  GOOGL        Alphabet Inc Class A  Information Technology
# 30           30   AMZN              Amazon.com Inc  Consumer Discretionary
# 372         372   PCLN           Priceline.com Inc  Consumer Discretionary
#
# ...

# %%
df.sort_values(by="Market Cap", ascending=False)
# Out:
#      Unnamed: 0 Symbol                   Name                  Sector  \
# 51           51   AAPL             Apple Inc.  Information Technology
# 27           27  GOOGL   Alphabet Inc Class A  Information Technology
# 28           28   GOOG   Alphabet Inc Class C  Information Technology
# 311         311   MSFT        Microsoft Corp.  Information Technology
# 30           30   AMZN         Amazon.com Inc  Consumer Discretionary
# ..          ...    ...                    ...                     ...
# 324         324   NAVI                Navient              Financials
# 386         386    RRC  Range Resources Corp.                  Energy
# 353         353   PDCO    Patterson Companies             Health Care
# 412         412    SIG        Signet Jewelers  Consumer Discretionary
# 104         104    CHK      Chesapeake Energy                  Energy
#
#        Price  Price/Earnings  Dividend Yield  Earnings/Share    Market Cap  \
# ...

# %%
df.sort_values(by=["Sector", "Market Cap"], ascending=False).head(40)
# Out:
#      Unnamed: 0 Symbol                              Name  \
# 332         332    NEE                    NextEra Energy
# 157         157    DUK                       Duke Energy
# 152         152      D                   Dominion Energy
# 417         417     SO                      Southern Co.
# 180         180    EXC                      Exelon Corp.
# 33           33    AEP           American Electric Power
# 410         410    SRE                     Sempra Energy
# 378         378    PEG      Public Serv. Enterprise Inc.
# 127         127     ED               Consolidated Edison
# 496         496    XEL                   Xcel Energy Inc
# 370         370    PPL                         PPL Corp.
# 362         362    PCG                        PG&E Corp.
# 165         165    EIX                      Edison Int'l
# 484         484    WEC              Wec Energy Group Inc
# 179         179     ES                 Eversource Energy
# ...

# %%
df.groupby(by="Sector").mean()
# Out:
#                             Unnamed: 0       Price  Price/Earnings  \
# Sector
# Consumer Discretionary      292.142857  124.034524       25.536024
# Consumer Staples            247.882353   79.764118       21.963235
# Energy                      239.218750   57.887500       38.559063
# Financials                  244.514706   89.056029       17.198971
# Health Care                 229.868852  132.515738       23.437833
# Industrials                 256.104478  116.887612       21.494328
# Information Technology      235.957143  119.242857       37.179857
# Materials                   261.440000  102.386800       20.542400
# Real Estate                 261.181818   88.712727       22.459091
# Telecommunication Services  210.333333   33.603333       11.190000
# Utilities                   233.071429   55.194643       16.846429
#
#                             Dividend Yield  Earnings/Share    Market Cap  \
# Sector
# ...

# %%
df.groupby(by="Sector").mean().sort_values(by="Dividend Yield", ascending=False)
# Out:
#                             Unnamed: 0       Price  Price/Earnings  \
# Sector
# Telecommunication Services  210.333333   33.603333       11.190000
# Real Estate                 261.181818   88.712727       22.459091
# Utilities                   233.071429   55.194643       16.846429
# Consumer Staples            247.882353   79.764118       21.963235
# Financials                  244.514706   89.056029       17.198971
# Energy                      239.218750   57.887500       38.559063
# Materials                   261.440000  102.386800       20.542400
# Consumer Discretionary      292.142857  124.034524       25.536024
# Industrials                 256.104478  116.887612       21.494328
# Information Technology      235.957143  119.242857       37.179857
# Health Care                 229.868852  132.515738       23.437833
#
#                             Dividend Yield  Earnings/Share    Market Cap  \
# Sector
# ...

# %%
df.groupby(by="Sector").sum()["Market Cap"].sort_values(ascending=False)
# Out:
# Sector
# Information Technology        6727121800912
# Financials                    3442649464852
# Health Care                   3244359043367
# Consumer Discretionary        3213562747315
# Industrials                   2411541173034
# Consumer Staples              2087076388082
# Energy                        1357313712749
# Materials                      692300259151
# Real Estate                    625315677562
# Utilities                      611632638471
# Telecommunication Services     453042743905
# Name: Market Cap, dtype: int64

# %%
pd.pivot_table(df[:50], values="Price", index=["Sector", "Name"])
# Out:
#                                                               Price
# Sector                 Name
# Consumer Discretionary Advance Auto Parts                    109.63
#                        Amazon.com Inc                       1350.50
# Consumer Staples       Altria Group Inc                       64.05
# Energy                 Anadarko Petroleum Corp                56.20
#                        Andeavor                               96.90
#                        Apache Corporation                     37.73
# Financials             AFLAC Inc                              83.25
#                        Affiliated Managers Group Inc         179.11
#                        Allstate Corp                          90.06
#                        American Express Co                    88.34
#                        American International Group, Inc.     58.28
#                        Ameriprise Financial                  152.50
# ...
