# %%
# %matplotlib inline
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = yf.download("AAPL", start="2015-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31  112.820000  113.129997  110.209999  110.379997  100.724174
# 2015-01-02  111.389999  111.440002  107.349998  109.330002   99.766006
# 2015-01-05  108.290001  108.650002  105.410004  106.250000   96.955429
# 2015-01-06  106.540001  107.430000  104.629997  106.260002   96.964584
# 2015-01-07  107.199997  108.199997  106.699997  107.750000   98.324242
# ...                ...         ...         ...         ...         ...
# 2020-08-10  450.399994  455.100006  440.000000  450.910004  450.910004
# 2020-08-11  447.880005  449.929993  436.429993  437.500000  437.500000
# 2020-08-12  441.989990  453.100006  441.190002  452.040009  452.040009
# 2020-08-13  457.720001  464.170013  455.709991  460.040009  460.040009
# 2020-08-14  459.320007  460.000000  452.179993  459.630005  459.630005
#
#               Volume
# Date
# 2014-12-31  41403400
# 2015-01-02  53204600
# 2015-01-05  64285500
# ...

# %%
df.plot()

# %%
df.plot(y="Adj Close", figsize=(15, 8))

# %%
top = plt.subplot2grid((4,1), (0, 0), rowspan=3, colspan=1)
top.plot(df.index, df["Adj Close"])

bottom = plt.subplot2grid((4,1), (3,0), rowspan=1, colspan=1)
bottom.bar(df.index, df['Volume'])

plt.gcf().set_size_inches(15,8)

# %%
data = yf.download("AAPL MSFT AMZN TSLA", start="2015-01-01")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data = data["Adj Close"]

# %%
data

# %%
data.plot(figsize=(15, 8))

# %%
ax = plt.gca()
data.plot(kind='line', ax=ax)
ax.set_yscale('log')
plt.gcf().set_size_inches(15,8)
