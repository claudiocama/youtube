# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({"c1": [0, 5, np.nan, 10, 15], "c2": [2, None, np.nan, 4, 6], "c3": [10, 20, np.nan, 40, 50], "c4": [100, 200, np.nan, 600, 800]})

# %%
df
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0  NaN  20.0  200.0
# 2   NaN  NaN   NaN    NaN
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df.isna()
# Out:
#       c1     c2     c3     c4
# 0  False  False  False  False
# 1  False   True  False  False
# 2   True   True   True   True
# 3  False  False  False  False
# 4  False  False  False  False

# %%
df.notna()
# Out:
#       c1     c2     c3     c4
# 0   True   True   True   True
# 1   True  False   True   True
# 2  False  False  False  False
# 3   True   True   True   True
# 4   True   True   True   True

# %%
df.dropna(how="all")
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0  NaN  20.0  200.0
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df.fillna(-1)
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0 -1.0  20.0  200.0
# 2  -1.0 -1.0  -1.0   -1.0
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df.fillna(method="ffill")
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0  2.0  20.0  200.0
# 2   5.0  2.0  20.0  200.0
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df.fillna(method="bfill")
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0  4.0  20.0  200.0
# 2  10.0  4.0  40.0  600.0
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df
# Out:
#      c1   c2    c3     c4
# 0   0.0  2.0  10.0  100.0
# 1   5.0  NaN  20.0  200.0
# 2   NaN  NaN   NaN    NaN
# 3  10.0  4.0  40.0  600.0
# 4  15.0  6.0  50.0  800.0

# %%
df.interpolate()
# Out:
#      c1        c2    c3     c4
# 0   0.0  2.000000  10.0  100.0
# 1   5.0  2.666667  20.0  200.0
# 2   7.5  3.333333  30.0  400.0
# 3  10.0  4.000000  40.0  600.0
# 4  15.0  6.000000  50.0  800.0
